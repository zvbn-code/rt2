# %%
import duckdb

# %%
duck = duckdb.connect()

# %%
duck.sql("""create or replace table ausfall as select * from read_csv('ausfall/2024*.csv')""")
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 duck.sql("""create or replace table ausfall as select * from read_csv('ausfall/2024*.csv')""")
#
# IOException: IO Error: No files found that match the pattern "ausfall/2024*.csv"
